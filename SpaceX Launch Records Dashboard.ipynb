# %%
# !pip install dash
# !pip install dash-bootstrap-components
# Out:
# Collecting dash
#   Downloading dash-3.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\steve\anaconda3\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\steve\anaconda3\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\steve\anaconda3\lib\site-packages (from dash) (5.24.1)
# Requirement already satisfied: importlib-metadata in c:\users\steve\anaconda3\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\steve\anaconda3\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in c:\users\steve\anaconda3\lib\site-packages (from dash) (2.32.3)
# Collecting retrying (from dash)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in c:\users\steve\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\steve\anaconda3\lib\site-packages (from dash) (80.9.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\steve\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\steve\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\steve\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\steve\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash) (1.6.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\steve\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.2.3)
# Requirement already satisfied: packaging in c:\users\steve\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (25.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\steve\anaconda3\lib\site-packages (from Werkzeug<3.2->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\steve\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\steve\anaconda3\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\steve\anaconda3\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\steve\anaconda3\lib\site-packages (from requests->dash) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\steve\anaconda3\lib\site-packages (from requests->dash) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\steve\anaconda3\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash) (0.4.6)
# Downloading dash-3.3.0-py3-none-any.whl (7.9 MB)
#    ---------------------------------------- 0.0/7.9 MB ? eta -:--:--
#    ------------- -------------------------- 2.6/7.9 MB 16.7 MB/s eta 0:00:01
#    ---------------------------------------- 7.9/7.9 MB 23.3 MB/s eta 0:00:00
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: retrying, dash
# Successfully installed dash-3.3.0 retrying-1.4.2
# Collecting dash-bootstrap-components
#   Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: dash>=3.0.4 in c:\users\steve\anaconda3\lib\site-packages (from dash-bootstrap-components) (3.3.0)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\steve\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (3.0.3)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\steve\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (3.0.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\steve\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (5.24.1)
# Requirement already satisfied: importlib-metadata in c:\users\steve\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (7.0.1)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\steve\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (4.11.0)
# Requirement already satisfied: requests in c:\users\steve\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (2.32.3)
# Requirement already satisfied: retrying in c:\users\steve\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (1.4.2)
# Requirement already satisfied: nest-asyncio in c:\users\steve\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\steve\anaconda3\lib\site-packages (from dash>=3.0.4->dash-bootstrap-components) (80.9.0)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\steve\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\steve\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\steve\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\steve\anaconda3\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (1.6.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\steve\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=3.0.4->dash-bootstrap-components) (8.2.3)
# Requirement already satisfied: packaging in c:\users\steve\anaconda3\lib\site-packages (from plotly>=5.0.0->dash>=3.0.4->dash-bootstrap-components) (25.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\steve\anaconda3\lib\site-packages (from Werkzeug<3.2->dash>=3.0.4->dash-bootstrap-components) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\steve\anaconda3\lib\site-packages (from importlib-metadata->dash>=3.0.4->dash-bootstrap-components) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\steve\anaconda3\lib\site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\steve\anaconda3\lib\site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\steve\anaconda3\lib\site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\steve\anaconda3\lib\site-packages (from requests->dash>=3.0.4->dash-bootstrap-components) (2025.10.5)
# Requirement already satisfied: colorama in c:\users\steve\anaconda3\lib\site-packages (from click>=8.1.3->Flask<3.2,>=1.0.4->dash>=3.0.4->dash-bootstrap-components) (0.4.6)
# Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl (204 kB)
# Installing collected packages: dash-bootstrap-components
# Successfully installed dash-bootstrap-components-2.0.4

# %%
# Import required libraries
import pandas as pd
import dash
from dash import html
from dash import dcc
from dash.dependencies import Input, Output
import plotly.express as px

# Read the airline data into pandas dataframe
spacex_df = pd.read_csv(r"C:\Users\steve\Downloads\spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()

# Create a dash application
app = dash.Dash(__name__)

# Create an app layout
# 1. Layout
app.layout = html.Div(children=[
    html.H1('SpaceX Launch Records Dashboard',
            style={'textAlign': 'center', 'color': '#503D36', 'font-size': 40}),
    
    # TASK 1: Launch site dropdown
    dcc.Dropdown(
        id='site-dropdown',
        options=[
            {'label': 'All Sites', 'value': 'ALL'},
            {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'},
            {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
            {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'},
            {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'},
        ],
        value='ALL',
        placeholder="Select a Launch Site here",
        searchable=True
    ),
    html.Br(),

    # TASK 2: Pie chart
    html.Div(dcc.Graph(id='success-pie-chart')),
    html.Br(),

    html.P("Payload range (Kg):"),

    # TASK 3: Payload slider
    dcc.RangeSlider(
        id='payload-slider',
        min=0,
        max=10000,
        step=1000,
        marks={0: '0', 2500: '2500', 5000: '5000', 7500: '7500', 10000: '10000'},
        value=[min_payload, max_payload]
    ),
    html.Br(),

    # TASK 4: Scatter chart
    html.Div(dcc.Graph(id='success-payload-scatter-chart')),
])

# 2. Callbacks
# TASK 2: Pie chart callback
@app.callback(
    Output('success-pie-chart', 'figure'),
    Input('site-dropdown', 'value')
)
def get_pie_chart(entered_site):
    filtered_df = spacex_df
    if entered_site == 'ALL':
        fig = px.pie(
            filtered_df,
            names='Launch Site',
            values='class',
            title='Total Successful Launches by Site'
        )
    else:
        site_df = filtered_df[filtered_df['Launch Site'] == entered_site]
        fig = px.pie(
            site_df,
            names='class',
            title=f'Success vs. Failed Launches for {entered_site}',
            color='class',
            color_discrete_map={1: 'green', 0: 'red'}
        )
    return fig

# TASK 4: Scatter chart callback
@app.callback(
    Output('success-payload-scatter-chart', 'figure'),
    [Input('site-dropdown', 'value'),
     Input('payload-slider', 'value')]
)
def update_scatter_chart(selected_site, payload_range):
    low, high = payload_range
    filtered_df = spacex_df[(spacex_df['Payload Mass (kg)'] >= low) &
                             (spacex_df['Payload Mass (kg)'] <= high)]
    
    if selected_site == 'ALL':
        fig = px.scatter(
            filtered_df, x='Payload Mass (kg)', y='class',
            color='Booster Version Category',
            title='Payload vs. Launch Outcome for All Sites'
        )
    else:
        site_df = filtered_df[filtered_df['Launch Site'] == selected_site]
        fig = px.scatter(
            site_df, x='Payload Mass (kg)', y='class',
            color='Booster Version Category',
            title=f'Payload vs. Launch Outcome for site {selected_site}'
        )
    return fig

# 3. Run the app
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
